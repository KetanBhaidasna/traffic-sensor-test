# %% [markdown]
# # Traffic Sensor Coding Test
#
# ## Honor Code
# Please complete this test without using AI coding assistants or external help. Use only official documentation if needed.
#
# ## Instructions
# You are provided with synthetic traffic sensor data from four intersections.
#
# ### Tasks:
# 1. Load and inspect the dataset.
# 2. Clean the data:
#    - Handle missing or corrupted rows based on the `Comments` column.
#    - Standardize formats if needed.
# 3. Create a new column:
#    - `Traffic Load Index = Vehicle Count + 2 * Pedestrian Count`
# 4. Group by `Intersection` and compute average `Traffic Load Index`.
# 5. Plot `Vehicle Count` vs `Pedestrian Count`, color-coded by `Signal Status`.
#
# ### Submission:
# - Save your completed notebook as `submission.ipynb`
# - Upload it via the provided form or email.

# %%
# Your code starts here
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("traffic_sensor_data.csv")
df.head()
